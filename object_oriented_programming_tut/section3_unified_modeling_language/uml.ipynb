# %% [markdown]
# Unified Modeling Language is a graphical way to represent Object Oriented Programming Models
# - (-) represents private access modifier/method
# - (#) represents protected access modifier/method
# - (+) represents public access modifier/method
#
# Inheritance is represented by an arrow point toward the base class
#
# Composition Relationship: reperesented by an arrow pointing and a filled diamond

# %% [markdown]
# Association Relationship (Not that important)
#
# ![image.png](attachment:image.png)
